# %%
from torcheeg.transforms.numpy.correlation import PearsonCorrelation
from torcheeg.datasets import BCICIV2aDataset
from torcheeg import transforms

SAMPLING_RATE = 250
SEQ_LENGTH = 500
DT=25

dataset = BCICIV2aDataset(
    root_path='../datasets/bci_c',
    io_path='.torcheeg/datasets_biciv_2a_correlation',
    chunk_size=SEQ_LENGTH,
    online_transform=transforms.PickElectrode([])
)

feature_extraction_ds = BCICIV2aDataset(
    root_path='../datasets/bci_c',
    io_path='.torcheeg/datasets_biciv_2a_feature_extraction',
    chunk_size=SEQ_LENGTH,
    overlap=SEQ_LENGTH - DT,
    num_worker=6,
)
# Out:
# [2024-02-17 23:08:11] INFO (torcheeg/MainThread) 🔍 | Detected cached processing results, reading cache from .torcheeg/datasets_biciv_2a_correlation.
# [2024-02-17 23:08:11] INFO (torcheeg/MainThread) 🔍 | Detected cached processing results, reading cache from .torcheeg/datasets_biciv_2a_feature_extraction.

# %%
# test pick channels

# %%
import numpy as np

samples = [sample for sample, _ in dataset]
samples = np.concatenate(samples, axis=-1)

# %%
# Correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(samples.transpose())
corr = df.corr()
# _, ax = plt.subplots(figsize=(16, 16))
# sns.heatmap(corr, annot=True, ax=ax)

# %%
corr.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_1abde_row0_col0, #T_1abde_row1_col1, #T_1abde_row2_col2, #T_1abde_row3_col3, #T_1abde_row4_col4, #T_1abde_row5_col5, #T_1abde_row6_col6, #T_1abde_row7_col7, #T_1abde_row8_col8, #T_1abde_row9_col9, #T_1abde_row10_col10, #T_1abde_row11_col11, #T_1abde_row12_col12, #T_1abde_row13_col13, #T_1abde_row14_col14, #T_1abde_row15_col15, #T_1abde_row16_col16, #T_1abde_row17_col17, #T_1abde_row18_col18, #T_1abde_row19_col19, #T_1abde_row20_col20, #T_1abde_row21_col21 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1abde_row0_col1, #T_1abde_row5_col11 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_1abde_row0_col2, #T_1abde_row0_col4, #T_1abde_row1_col3, #T_1abde_row3_col1, #T_1abde_row8_col14, #T_1abde_row11_col5 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_1abde_row0_col3, #T_1abde_row8_col7, #T_1abde_row11_col12, #T_1abde_row14_col8 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_1abde_row0_col5, #T_1abde_row10_col2, #T_1abde_row10_col8 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_1abde_row0_col6, #T_1abde_row13_col16 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1abde_row0_col7, #T_1abde_row6_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_1abde_row0_col8, #T_1abde_row0_col10, #T_1abde_row1_col13, #T_1abde_row5_col16, #T_1abde_row18_col17 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_1abde_row0_col9, #T_1abde_row3_col15, #T_1abde_row18_col7, #T_1abde_row19_col8 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_1abde_row0_col11, #T_1abde_row5_col15 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_1abde_row0_col12, #T_1abde_row4_col19 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_1abde_row0_col13, #T_1abde_row0_col14, #T_1abde_row0_col15, #T_1abde_row0_col16, #T_1abde_row0_col18, #T_1abde_row0_col19, #T_1abde_row0_col20, #T_1abde_row0_col21, #T_1abde_row6_col17, #T_1abde_row21_col0, #T_1abde_row21_col1, #T_1abde_row21_col2, #T_1abde_row21_col3, #T_1abde_row21_col4, #T_1abde_row21_col5, #T_1abde_row21_col6, #T_1abde_row21_col7, #T_1abde_row21_col8, #T_1abde_row21_col9, #T_1abde_row21_col10, #T_1abde_row21_col11, #T_1abde_row21_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1abde_row0_col17 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_1abde_row1_col0, #T_1abde_row9_col2, #T_1abde_row16_col10 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_1abde_row1_col2, #T_1abde_row19_col18, #T_1abde_row20_col19 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_1abde_row1_col4, #T_1abde_row5_col10, #T_1abde_row6_col1, #T_1abde_row8_col15, #T_1abde_row14_col7, #T_1abde_row18_col14, #T_1abde_row19_col16 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_1abde_row1_col5, #T_1abde_row18_col15 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_1abde_row1_col6, #T_1abde_row1_col8, #T_1abde_row8_col13, #T_1abde_row9_col5, #T_1abde_row16_col14 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_1abde_row1_col7, #T_1abde_row14_col19 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_1abde_row1_col9, #T_1abde_row6_col8, #T_1abde_row17_col5 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_1abde_row1_col10, #T_1abde_row5_col17, #T_1abde_row11_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_1abde_row1_col11, #T_1abde_row7_col20 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1abde_row1_col12, #T_1abde_row3_col17, #T_1abde_row3_col19, #T_1abde_row4_col18, #T_1abde_row18_col4, #T_1abde_row19_col12 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1abde_row1_col14, #T_1abde_row2_col12 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_1abde_row1_col15, #T_1abde_row12_col8 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_1abde_row1_col16, #T_1abde_row7_col17, #T_1abde_row12_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1abde_row1_col17 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_1abde_row1_col18 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_1abde_row1_col19, #T_1abde_row18_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_1abde_row1_col20, #T_1abde_row3_col21 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_1abde_row1_col21 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col0, #T_1abde_row4_col0, #T_1abde_row10_col9, #T_1abde_row16_col20, #T_1abde_row17_col16, #T_1abde_row19_col21 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col1, #T_1abde_row4_col5, #T_1abde_row5_col4, #T_1abde_row19_col20 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col4, #T_1abde_row16_col17 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col5, #T_1abde_row5_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col6, #T_1abde_row11_col9, #T_1abde_row12_col10, #T_1abde_row16_col5 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_1abde_row2_col7, #T_1abde_row9_col14, #T_1abde_row14_col16, #T_1abde_row19_col14 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_1abde_row2_col8, #T_1abde_row5_col0, #T_1abde_row7_col13, #T_1abde_row11_col10, #T_1abde_row11_col17, #T_1abde_row15_col19, #T_1abde_row17_col11, #T_1abde_row21_col19 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col9, #T_1abde_row4_col1, #T_1abde_row4_col9 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col10, #T_1abde_row7_col14, #T_1abde_row17_col10 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_1abde_row2_col11, #T_1abde_row16_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_1abde_row2_col13, #T_1abde_row3_col12 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_1abde_row2_col14, #T_1abde_row14_col17 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_1abde_row2_col15 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_1abde_row2_col16, #T_1abde_row7_col21, #T_1abde_row21_col17 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1abde_row2_col17 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_1abde_row2_col18 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_1abde_row2_col19, #T_1abde_row11_col6, #T_1abde_row21_col13 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_1abde_row2_col20, #T_1abde_row4_col13 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_1abde_row2_col21, #T_1abde_row18_col11 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1abde_row3_col0, #T_1abde_row8_col2, #T_1abde_row8_col9, #T_1abde_row9_col8, #T_1abde_row15_col14, #T_1abde_row18_col21 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_1abde_row3_col2, #T_1abde_row3_col4, #T_1abde_row4_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_1abde_row3_col5, #T_1abde_row7_col6, #T_1abde_row7_col8, #T_1abde_row12_col11, #T_1abde_row13_col7, #T_1abde_row18_col20, #T_1abde_row20_col18 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_1abde_row3_col6, #T_1abde_row6_col14 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_1abde_row3_col7, #T_1abde_row10_col19, #T_1abde_row11_col2, #T_1abde_row14_col1, #T_1abde_row16_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_1abde_row3_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_1abde_row3_col9, #T_1abde_row6_col7, #T_1abde_row8_col3, #T_1abde_row9_col15, #T_1abde_row20_col16 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_1abde_row3_col10 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_1abde_row3_col11, #T_1abde_row17_col4 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_1abde_row3_col13, #T_1abde_row12_col15 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_1abde_row3_col14, #T_1abde_row3_col16, #T_1abde_row11_col14, #T_1abde_row12_col9, #T_1abde_row13_col0, #T_1abde_row17_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1abde_row3_col18, #T_1abde_row7_col12, #T_1abde_row12_col6, #T_1abde_row19_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_1abde_row3_col20 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #

# %%
def get_top_correlations(df, threshold=0.4):
    """
    df: the dataframe to get correlations from
    threshold: the maximum and minimum value to include for correlations. For eg, if this is 0.4, only pairs haveing a correlation coefficient greater than 0.4 or less than -0.4 will be included in the results. 
    """
    orig_corr = df.corr()
    c = orig_corr.abs()

    so = c.unstack()

    print("|    Variable 1    |    Variable 2    | Correlation Coefficient    |")
    print("|------------------|------------------|----------------------------|")
    
    i=0
    pairs=set()
    result = pd.DataFrame()
    for index, value in so.sort_values(ascending=False).items():
        # Exclude duplicates and self-correlations
        if value > threshold \
        and index[0] != index[1] \
        and (index[0], index[1]) not in pairs \
        and (index[1], index[0]) not in pairs:
            
            print(f'|    {index[0]}    |    {index[1]}    |    {orig_corr.loc[(index[0], index[1])]}    |')
            result.loc[i, ['Variable 1', 'Variable 2', 'Correlation Coefficient']] = [index[0], index[1], orig_corr.loc[(index[0], index[1])]]
            pairs.add((index[0], index[1]))
            i+=1
    return result.reset_index(drop=True).set_index(['Variable 1', 'Variable 2'])


thresholded_corr = get_top_correlations(corr, threshold=0.85)
# Out:
# |    Variable 1    |    Variable 2    | Correlation Coefficient    |
# |------------------|------------------|----------------------------|
# |    2    |    3    |    0.9733597093218412    |
# |    1    |    2    |    0.9692441775827345    |
# |    3    |    4    |    0.9690379499313186    |
# |    18    |    19    |    0.9682252941968382    |
# |    4    |    5    |    0.9669950567890588    |
# |    19    |    20    |    0.9662997863457256    |
# |    19    |    21    |    0.9655171457894206    |
# |    12    |    11    |    0.9603220194631279    |
# |    3    |    0    |    0.9587000186538038    |
# |    21    |    20    |    0.9489536511277675    |
# |    18    |    21    |    0.9488435514504877    |
# |    6    |    7    |    0.9475564103974222    |
# |    21    |    0    |    -0.9438175224082204    |
# |    0    |    2    |    0.9387367888644301    |
# |    0    |    4    |    0.9369301030299947    |
# |    16    |    17    |    0.9135738671816046    |
# |    4    |    2    |    0.9017011979887254    |
# |    3    |    1    |    0.9007672840559301    |
# |    13    |    14    |    0.8946996628580193    |
# |    1    |    0    |    0.8916826656063631    |
# |    15    |    14    |    0.8908036036152203    |
# |    5    |    3    |    0.8870282910309479    |
# |    8    |    7    |    0.8861516711981836    |
# |    18    |    20    |    0.8855054440122953    |
# |    9    |    8    |    0.8840697713276787    |
# |    5    |    0    |    0.8810512747060361    |
# |    18    |    0    |    -0.8775799319014917    |
# |    11    |    10    |    0.8772332457296156    |
# |    1    |    21    |    -0.8611490771892903    |
# |    0    |    19    |    -0.8595860716173214    |
# |    10    |    9    |    0.8544486782346973    |
# |    2    |    21    |    -0.8526743807620805    |

# %% [markdown]
# |    Variable 1    |    Variable 2    | Correlation Coefficient    |
# |------------------|------------------|----------------------------|
# |    2    |    3    |    0.9733597093218412    |
# |    1    |    2    |    0.9692441775827345    |
# |    3    |    4    |    0.9690379499313186    |
# |    18    |    19    |    0.9682252941968382    |
# |    4    |    5    |    0.9669950567890588    |
# |    19    |    20    |    0.9662997863457256    |
# |    19    |    21    |    0.9655171457894206    |
# |    12    |    11    |    0.9603220194631279    |
# |    3    |    0    |    0.9587000186538038    |
# |    21    |    20    |    0.9489536511277675    |
# |    18    |    21    |    0.9488435514504877    |
# |    6    |    7    |    0.9475564103974222    |
# |    21    |    0    |    -0.9438175224082204    |
# |    0    |    2    |    0.9387367888644301    |
# |    0    |    4    |    0.9369301030299947    |
# |    16    |    17    |    0.9135738671816046    |
# |    4    |    2    |    0.9017011979887254    |
# |    3    |    1    |    0.9007672840559301    |
# |    13    |    14    |    0.8946996628580193    |
# |    1    |    0    |    0.8916826656063631    |
# |    15    |    14    |    0.8908036036152203    |
# |    5    |    3    |    0.8870282910309479    |
# |    8    |    7    |    0.8861516711981836    |
# |    18    |    20    |    0.8855054440122953    |
# |    9    |    8    |    0.8840697713276787    |
# |    5    |    0    |    0.8810512747060361    |
# |    18    |    0    |    -0.8775799319014917    |
# |    11    |    10    |    0.8772332457296156    |
# |    1    |    21    |    -0.8611490771892903    |
# |    0    |    19    |    -0.8595860716173214    |
# |    10    |    9    |    0.8544486782346973    |
# |    2    |    21    |    -0.8526743807620805    |
# |    21    |    3    |    -0.849215314686478    |
# |    20    |    0    |    -0.8489561188060041    |
# |    15    |    16    |    0.8374887060596466    |
# |    16    |    20    |    0.8333164717467622    |
# |    1    |    20    |    -0.8296570038463833    |
# |    21    |    4    |    -0.8224395523144938    |
# |    19    |    15    |    0.8084976006037484    |
# |    4    |    10    |    0.8060531859846514    |
# |    5    |    10    |    0.8054969643665818    |
# |    2    |    8    |    0.803065648443115    |

# %%
thresholded_corr.sort_values(by='Variable 1').style.format(precision=3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e119">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e119_level0_col0" class="col_heading level0 col0" >Correlation Coefficient</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable 1</th>
#       <th class="index_name level1" >Variable 2</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e119_level0_row0" class="row_heading level0 row0" rowspan="2">0.000000</th>
#       <th id="T_4e119_level1_row0" class="row_heading level1 row0" >2.000000</th>
#       <td id="T_4e119_row0_col0" class="data row0 col0" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level1_row1" class="row_heading level1 row1" >4.000000</th>
#       <td id="T_4e119_row1_col0" class="data row1 col0" >0.937</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row2" class="row_heading level0 row2" >1.000000</th>
#       <th id="T_4e119_level1_row2" class="row_heading level1 row2" >2.000000</th>
#       <td id="T_4e119_row2_col0" class="data row2 col0" >0.969</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row3" class="row_heading level0 row3" >2.000000</th>
#       <th id="T_4e119_level1_row3" class="row_heading level1 row3" >3.000000</th>
#       <td id="T_4e119_row3_col0" class="data row3 col0" >0.973</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row4" class="row_heading level0 row4" rowspan="3">3.000000</th>
#       <th id="T_4e119_level1_row4" class="row_heading level1 row4" >4.000000</th>
#       <td id="T_4e119_row4_col0" class="data row4 col0" >0.969</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level1_row5" class="row_heading level1 row5" >0.000000</th>
#       <td id="T_4e119_row5_col0" class="data row5 col0" >0.959</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level1_row6" class="row_heading level1 row6" >1.000000</th>
#       <td id="T_4e119_row6_col0" class="data row6 col0" >0.901</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row7" class="row_heading level0 row7" rowspan="2">4.000000</th>
#       <th id="T_4e119_level1_row7" class="row_heading level1 row7" >5.000000</th>
#       <td id="T_4e119_row7_col0" class="data row7 col0" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level1_row8" class="row_heading level1 row8" >2.000000</th>
#       <td id="T_4e119_row8_col0" class="data row8 col0" >0.902</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row9" class="row_heading level0 row9" >6.000000</th>
#       <th id="T_4e119_level1_row9" class="row_heading level1 row9" >7.000000</th>
#       <td id="T_4e119_row9_col0" class="data row9 col0" >0.948</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row10" class="row_heading level0 row10" >12.000000</th>
#       <th id="T_4e119_level1_row10" class="row_heading level1 row10" >11.000000</th>
#       <td id="T_4e119_row10_col0" class="data row10 col0" >0.960</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row11" class="row_heading level0 row11" >16.000000</th>
#       <th id="T_4e119_level1_row11" class="row_heading level1 row11" >17.000000</th>
#       <td id="T_4e119_row11_col0" class="data row11 col0" >0.914</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row12" class="row_heading level0 row12" rowspan="2">18.000000</th>
#       <th id="T_4e119_level1_row12" class="row_heading level1 row12" >19.000000</th>
#       <td id="T_4e119_row12_col0" class="data row12 col0" >0.968</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level1_row13" class="row_heading level1 row13" >21.000000</th>
#       <td id="T_4e119_row13_col0" class="data row13 col0" >0.949</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row14" class="row_heading level0 row14" rowspan="2">19.000000</th>
#       <th id="T_4e119_level1_row14" class="row_heading level1 row14" >21.000000</th>
#       <td id="T_4e119_row14_col0" class="data row14 col0" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level1_row15" class="row_heading level1 row15" >20.000000</th>
#       <td id="T_4e119_row15_col0" class="data row15 col0" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level0_row16" class="row_heading level0 row16" rowspan="2">21.000000</th>
#       <th id="T_4e119_level1_row16" class="row_heading level1 row16" >0.000000</th>
#       <td id="T_4e119_row16_col0" class="data row16 col0" >-0.944</td>
#     </tr>
#     <tr>
#       <th id="T_4e119_level1_row17" class="row_heading level1 row17" >20.000000</th>
#       <td id="T_4e119_row17_col0" class="data row17 col0" >0.949</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Se escogen
[5,7,8,9,10,11,13,14,15,17,20]
